# %% [markdown]
# # Matplotlib
# Read the links https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before starting the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
#Answer: There are two ways in which you can use Matplotlib, either you go the object oriented
#way where you explicitly create Figure and Axes OR you rely on pyplot to do it for you.
#The recommended approach is to take the object oriented approach. The reason for this
#is that when a solution becomes more complex you want to stick with OO approach for clarity

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
#Answer: Let us break down what each object is first:
# 1. Figure = This is the canvas, the drawing surface. It contains one or more Axes. You can set things like title and legend.
# 2. Axes = This is the coordinate system which contains one or more Axis objects
# 3. Axis = Represents x or y axis and its properties like ticks, scale and label
# 4. Artist = This object, the artist is the abstract base class of Figure and Axes.

#So, Figure and Axes are special cases of an Artist object which is used to draw diagrams.
#Axis on the other hand you get from Axes to set for instance the ticks for x or y axis.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
#Answer: The expected input type is a numpy array. Otherwise you can get some unpredicted results

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
arr = np.linspace(-4, 4, 400)
powerArr = arr**2

# Object Oriented Approach
fig, ax = plt.subplots(figsize=(6, 3))
ax.plot(arr, powerArr, color='blue', linestyle='--')
ax.set_title('Object oriented approach')
ax.set_xlabel('x')
ax.set_ylabel('y')


# pyplot approach
plt.subplots(figsize=(6, 3))
plt.plot(arr, powerArr, color='black', linestyle=':')
plt.title('pyplot approach')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# Scatter figure
fig, axs = plt.subplots(1, 2, figsize=(10, 4), layout='constrained')
axs[0].scatter(random_data_x, random_data_y, s=50, facecolor='C0', edgecolor='k')
axs[0].set_title('Scatter plot')
axs[0].set_ylabel('y')
axs[0].set_xlabel('x')

# Bar figure
axs[1].bar(names, values, color=['#6a3d9a', '#1f78b4', '#33a02c', '#ff7f00', '#e31a1c'])
axs[1].set_title('Bar plot')
axs[1].set_ylabel('Amount')
axs[1].set_xlabel('Fruits')
# Out:
# Text(0.5, 0, 'Fruits')
