# %% [markdown]
# **I denna del besvaras 3 frågor kring självutvärdering**

# %% [markdown]
# 1. Har något varit utmanande i kursen/kunskapskontrollerna? Om ja, hur har du hanterat det?
# Svar: Det har varit utmanande att förstå alla koncepten och begreppen samt hur man korrekt använder dessa. Jag känner att mitt arbete kring AI Ticker systemet har givit mig en djupare inblick i hur man ska använda begreppen och olika utvärderingsmått.

# %% [markdown]
# 2. Vilket betyg anser du att du ska ha och varför?
# Svar: Genom mitt eget arbete och utvecklade system för aktieanalys som jag lagt ner en hel del arbete på (mycket för att jag tycker att det varit oerhört roligt och lärorikt) så känner jag att ett VG är relativt motiverat ;)
# Analysen är väl underbyggd och även om inte systemet är till 100% driftsatt så finns alla delar på plats, det finns ett deployat backend-system och det finns en front-end som kan ställa frågor mot mitt backend-api för aktieprediktion.

# %% [markdown]
# 3. Något du vill lyfta fram till Terese?
# Svar: Som alltid, du är oerhört pedagogisk och det är fantastikts att ha dig som lärare!
